# %%
import pandas as pd
import numpy as np
import geopy.distance
from ast import literal_eval
import datetime as dt

# %%
# pip install geopy

# %%
stations = pd.read_csv("GetNearestBusAndTrainStation.csv")
stations = stations.drop(columns="Unnamed: 0")
stations
# Out:
#                        ID                             Station Name  \
# 0     1594046383808271024                   Troy St & Jackson Blvd
# 1                     641      Central Park Ave & Bloomingdale Ave
# 2     1683527931525155814      Public Rack - Cornell Ave & 87th Pl
# 3                     367                     Racine Ave & 35th St
# 4     1673852313397164648  Public Rack - Francisco Ave & Touhy Ave
# ...                   ...                                      ...
# 1414  1715846705501012844   Public Rack - Lawndale Ave & Roosevelt
# 1415  1715846718385914742      Public Rack - Ashland Ave & 74th St
# 1416                  320                 Loomis St & Lexington St
# 1417                   54                  Ogden Ave & Chicago Ave
# 1418                  693                  Baltimore Ave & 87th St
#
#       Total Docks  Docks in Service      Status   Latitude  Longitude  \
# 0               9                 9  In Service  41.877505 -87.704850
# 1              11                11  In Service  41.914166 -87.716755
# 2               1                 1  In Service  41.736881 -87.583146
# 3              15                15  In Service  41.830689 -87.656211
# 4               2                 2  In Service  42.011865 -87.701317
# ...           ...               ...         ...        ...        ...
# 1414            2                 2  In Service  41.866225 -87.717918
# 1415            2                 2  In Service  41.759735 -87.663736
# 1416           19                19  In Service  41.872187 -87.661501
# 1417           19                19  In Service  41.896362 -87.654061
# 1418           15                15  In Service  41.737336 -87.548515
#
#                                       Location  \
# 0                       (41.877505, -87.70485)
# 1                      (41.914166, -87.716755)
# 2                  (41.73688127, -87.58314552)
# 3      (41.83068856472101, -87.65621066093445)
# 4                      (42.011865, -87.701317)
# ...                                        ...
# 1414                   (41.866225, -87.717918)
# 1415                   (41.759735, -87.663736)
# 1416                   (41.872187, -87.661501)
# 1417            (41.896362458, -87.6540612729)
# 1418  (41.737335600416664, -87.54851460456847)
#
#              nearest_bus_station_name  nearest_bus_station_distance  \
# 0                    Jackson & Kedzie                      0.081453
# 1             Armitage & Central Park                      0.342105
# 2              87th Street & East End                      0.020426
# 3                35th Street & Racine                      0.050069
# 4                   Touhy & Francisco                      0.072283
# ...                               ...                           ...
# 1414             Roosevelt & Lawndale                      0.005609
# 1415            74th Street & Ashland                      0.034132
# 1416                Harrison & Loomis                      0.217218
# 1417  Chicago & Milwaukee (Blue Line)                      0.086847
# 1418          87th Street & Baltimore                      0.033402
#
#      nearest_train_station_name  nearest_train_station_distance
# 0                  Kedzie-Homan                        0.365048
# 1                  Logan Square                        1.857948
# 2                          87th                        3.462482
# 3                       Ashland                        1.213685
# 4                        Howard                        2.486505
# ...                         ...                             ...
# 1414                    Pulaski                        1.058657
# 1415               Ashland/63rd                        2.124192
# 1416                     Racine                        0.447972
# 1417                    Chicago                        0.100847
# 1418                       87th                        6.343170
#
# [1419 rows x 12 columns]

# %%
stations["efficiency"] = 0
stations
# Out:
#                        ID                             Station Name  \
# 0     1594046383808271024                   Troy St & Jackson Blvd
# 1                     641      Central Park Ave & Bloomingdale Ave
# 2     1683527931525155814      Public Rack - Cornell Ave & 87th Pl
# 3                     367                     Racine Ave & 35th St
# 4     1673852313397164648  Public Rack - Francisco Ave & Touhy Ave
# ...                   ...                                      ...
# 1414  1715846705501012844   Public Rack - Lawndale Ave & Roosevelt
# 1415  1715846718385914742      Public Rack - Ashland Ave & 74th St
# 1416                  320                 Loomis St & Lexington St
# 1417                   54                  Ogden Ave & Chicago Ave
# 1418                  693                  Baltimore Ave & 87th St
#
#       Total Docks  Docks in Service      Status   Latitude  Longitude  \
# 0               9                 9  In Service  41.877505 -87.704850
# 1              11                11  In Service  41.914166 -87.716755
# 2               1                 1  In Service  41.736881 -87.583146
# 3              15                15  In Service  41.830689 -87.656211
# 4               2                 2  In Service  42.011865 -87.701317
# ...           ...               ...         ...        ...        ...
# 1414            2                 2  In Service  41.866225 -87.717918
# 1415            2                 2  In Service  41.759735 -87.663736
# 1416           19                19  In Service  41.872187 -87.661501
# 1417           19                19  In Service  41.896362 -87.654061
# 1418           15                15  In Service  41.737336 -87.548515
#
#                                       Location  \
# 0                       (41.877505, -87.70485)
# 1                      (41.914166, -87.716755)
# 2                  (41.73688127, -87.58314552)
# 3      (41.83068856472101, -87.65621066093445)
# 4                      (42.011865, -87.701317)
# ...                                        ...
# 1414                   (41.866225, -87.717918)
# 1415                   (41.759735, -87.663736)
# 1416                   (41.872187, -87.661501)
# 1417            (41.896362458, -87.6540612729)
# 1418  (41.737335600416664, -87.54851460456847)
#
#              nearest_bus_station_name  nearest_bus_station_distance  \
# 0                    Jackson & Kedzie                      0.081453
# 1             Armitage & Central Park                      0.342105
# 2              87th Street & East End                      0.020426
# 3                35th Street & Racine                      0.050069
# 4                   Touhy & Francisco                      0.072283
# ...                               ...                           ...
# 1414             Roosevelt & Lawndale                      0.005609
# 1415            74th Street & Ashland                      0.034132
# 1416                Harrison & Loomis                      0.217218
# 1417  Chicago & Milwaukee (Blue Line)                      0.086847
# 1418          87th Street & Baltimore                      0.033402
#
#      nearest_train_station_name  nearest_train_station_distance  efficiency
# 0                  Kedzie-Homan                        0.365048           0
# 1                  Logan Square                        1.857948           0
# 2                          87th                        3.462482           0
# 3                       Ashland                        1.213685           0
# 4                        Howard                        2.486505           0
# ...                         ...                             ...         ...
# 1414                    Pulaski                        1.058657           0
# 1415               Ashland/63rd                        2.124192           0
# 1416                     Racine                        0.447972           0
# 1417                    Chicago                        0.100847           0
# 1418                       87th                        6.343170           0
#
# [1419 rows x 13 columns]

# %%
hist = pd.read_csv("Divvy_Bicycle_Stations_-_Historical_hourly.csv")
trips = pd.read_csv("divvy_trips_data_final.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 hist = pd.read_csv("Divvy_Bicycle_Stations_-_Historical_hourly.csv")
#       2 trips = pd.read_csv("divvy_trips_data_final.csv")
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Divvy_Bicycle_Stations_-_Historical_hourly.csv'

# %%
trips["date"]=pd.to_datetime(trips["start_time"]).dt.date
demand=trips.value_counts(["start_station_name", "date"]).to_frame('counts')
demand.to_csv("./demand.csv")
demand.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 trips["date"]=pd.to_datetime(trips["start_time"]).dt.date
#       2 demand=trips.value_counts(["start_station_name", "date"]).to_frame('counts')
#       3 demand.to_csv("./demand.csv")
#
# NameError: name 'trips' is not defined

# %%
hist=hist.loc[hist["Status"]=="In Service"]
hist["date"]=pd.to_datetime(hist["Timestamp"]).dt.date
hist["Available Bikes"]=hist["Available Bikes"].astype(int)
supply = hist.groupby(["Station Name","date"])["Available Bikes"].sum().to_frame()
supply.to_csv("./supply.csv")
supply.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 hist=hist.loc[hist["Status"]=="In Service"]
#       2 hist["date"]=pd.to_datetime(hist["Timestamp"]).dt.date
#       3 hist["Available Bikes"]=hist["Available Bikes"].astype(int)
#
# NameError: name 'hist' is not defined

# %%
s = pd.read_csv("supply.csv")
s=s.sort_values(by=["Station Name","date"])
d = pd.read_csv("demand.csv")
d=d.sort_values(by=["start_station_name", "date"])

# %%
d["ratio"]=0

# %%
for i in d.index:
    label = s.loc[(s["Station Name"]==d["start_station_name"][i]) & (s["date"]==d["date"][i])]["Available Bikes"]
    if len(label) !=0:
        d["ratio"][i]=float((label/d["counts"][i]).values)

# %%
ratio=d.groupby(["start_station_name"]).mean()
ratio.to_csv("./ratio.csv")

# %%
stations["Supply_to_Demand"]=0
stations["Demand"]=0
ratios = pd.read_csv("ratio.csv")
for i in stations.index:
    stations["nearest_train_station_distance"][i] = stations["nearest_train_station_distance"][i] * 0.621
    stations["nearest_bus_station_distance"][i] = stations["nearest_bus_station_distance"][i] * 0.621
    ind1=ratios.loc[ratios["start_station_name"]==stations["Station Name"][i]]["counts"]
    ind2=ratios.loc[ratios["start_station_name"]==stations["Station Name"][i]]["ratio"]
    if len(ind1)!=0 and len(ind2)!=0:
        stations["Demand"][i]=ind1.values
        stations["Supply_to_Demand"][i]=ind2.values
stations
# Out:
# /var/folders/d5/kbrmypln0nnfft9htnrprljc0000gp/T/ipykernel_8588/1325862165.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations["nearest_train_station_distance"][i] = stations["nearest_train_station_distance"][i] * 0.621
# /var/folders/d5/kbrmypln0nnfft9htnrprljc0000gp/T/ipykernel_8588/1325862165.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations["nearest_bus_station_distance"][i] = stations["nearest_bus_station_distance"][i] * 0.621
# /var/folders/d5/kbrmypln0nnfft9htnrprljc0000gp/T/ipykernel_8588/1325862165.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations["Demand"][i]=ind1.values
# /var/folders/d5/kbrmypln0nnfft9htnrprljc0000gp/T/ipykernel_8588/1325862165.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations["Supply_to_Demand"][i]=ind2.values
#                 ID                             Station Name  Total Docks  \
# 0     1.594050e+18                   Troy St & Jackson Blvd            9
# 1     6.410000e+02      Central Park Ave & Bloomingdale Ave           11
# 2     1.683530e+18      Public Rack - Cornell Ave & 87th Pl            1
# 3     3.670000e+02                     Racine Ave & 35th St           15
# 4     1.673850e+18  Public Rack - Francisco Ave & Touhy Ave            2
# ...            ...                                      ...          ...
# 1414  1.715850e+18   Public Rack - Lawndale Ave & Roosevelt            2
# 1415  1.715850e+18      Public Rack - Ashland Ave & 74th St            2
# 1416  3.200000e+02                 Loomis St & Lexington St           19
# 1417  5.400000e+01                  Ogden Ave & Chicago Ave           19
# 1418  6.930000e+02                  Baltimore Ave & 87th St           15
#
#       Docks in Service      Status   Latitude  Longitude  \
# 0                    9  In Service  41.877505 -87.704850
# 1                   11  In Service  41.914166 -87.716755
# 2                    1  In Service  41.736881 -87.583146
# 3                   15  In Service  41.830689 -87.656211
# 4                    2  In Service  42.011865 -87.701317
# ...                ...         ...        ...        ...
# 1414                 2  In Service  41.866225 -87.717918
# 1415                 2  In Service  41.759735 -87.663736
# 1416                19  In Service  41.872187 -87.661501
# 1417                19  In Service  41.896362 -87.654061
# 1418                15  In Service  41.737336 -87.548515
#
#                                       Location nearest_train_station_name  \
# 0                       (41.877505, -87.70485)               Kedzie-Homan
# 1                      (41.914166, -87.716755)               Logan Square
# 2                  (41.73688127, -87.58314552)                       87th
# 3      (41.83068856472101, -87.65621066093445)                    Ashland
# 4                      (42.011865, -87.701317)                     Howard
# ...                                        ...                        ...
# 1414                   (41.866225, -87.717918)                    Pulaski
# 1415                   (41.759735, -87.663736)               Ashland/63rd
# 1416                   (41.872187, -87.661501)                     Racine
# 1417            (41.896362458, -87.6540612729)                    Chicago
# 1418  (41.737335600416664, -87.54851460456847)                       87th
#
#       nearest_train_station_distance         nearest_bus_station_name  \
# 0                           0.140777                 Jackson & Kedzie
# 1                           0.716501          Armitage & Central Park
# 2                           1.335275           87th Street & East End
# 3                           0.468047             35th Street & Racine
# 4                           0.958898                Touhy & Francisco
# ...                              ...                              ...
# 1414                        0.408262             Roosevelt & Lawndale
# 1415                        0.819176            74th Street & Ashland
# 1416                        0.172757                Harrison & Loomis
# 1417                        0.038891  Chicago & Milwaukee (Blue Line)
# 1418                        2.446187          87th Street & Baltimore
#
#       nearest_bus_station_distance  efficiency  Supply_to_Demand     Demand
# 0                         0.031412           0         34.557692   1.346154
# 1                         0.131930           0         36.836575   7.582558
# 2                         0.007877           0          8.100000   1.200000
# 3                         0.019309           0         71.602211   3.347193
# 4                         0.027875           0          9.500000   1.000000
# ...                            ...         ...               ...        ...
# 1414                      0.002163           0          0.000000   0.000000
# 1415                      0.013163           0          0.000000   0.000000
# 1416                      0.083768           0         12.757780  37.920830
# 1417                      0.033492           0         21.361908  26.010023
# 1418                      0.012881           0         48.765399   3.148026
#
# [1419 rows x 15 columns]

# %%
bus_weight = 0.5
train_weight = 0.3
dist_s1_weight = 0.8
dist_s2_weight = 0.5
dist_s3_weight = 0.3
stod_weight = 1.5

def find_efficiency(station_data):
    for i in range(len(station_data)):
        efficiency = station_data.loc[i]["nearest_bus_station_distance"] * bus_weight
        efficiency = efficiency + station_data.loc[i]["nearest_train_station_distance"] * train_weight
        

        dist = []
        for j in range(len(station_data)):
            if i != j:
                dist.append(geopy.distance.geodesic(literal_eval(station_data.loc[i]["Location"]), literal_eval(station_data.loc[j]["Location"])).miles)
        dist.sort()

        efficiency = efficiency + dist[0]*dist_s1_weight
        efficiency = efficiency + dist[1]*dist_s2_weight
        efficiency = efficiency + dist[2]*dist_s3_weight
        
        efficiency = efficiency + station_data.loc[i]["Supply_to_Demand"] * stod_weight

        station_data.loc[i,"efficiency"] = efficiency

# %%
find_efficiency(stations)
stations
# Out:
#                 ID                             Station Name  Total Docks  \
# 0     1.594050e+18                   Troy St & Jackson Blvd            9
# 1     6.410000e+02      Central Park Ave & Bloomingdale Ave           11
# 2     1.683530e+18      Public Rack - Cornell Ave & 87th Pl            1
# 3     3.670000e+02                     Racine Ave & 35th St           15
# 4     1.673850e+18  Public Rack - Francisco Ave & Touhy Ave            2
# ...            ...                                      ...          ...
# 1414  1.715850e+18   Public Rack - Lawndale Ave & Roosevelt            2
# 1415  1.715850e+18      Public Rack - Ashland Ave & 74th St            2
# 1416  3.200000e+02                 Loomis St & Lexington St           19
# 1417  5.400000e+01                  Ogden Ave & Chicago Ave           19
# 1418  6.930000e+02                  Baltimore Ave & 87th St           15
#
#       Docks in Service      Status   Latitude  Longitude  \
# 0                    9  In Service  41.877505 -87.704850
# 1                   11  In Service  41.914166 -87.716755
# 2                    1  In Service  41.736881 -87.583146
# 3                   15  In Service  41.830689 -87.656211
# 4                    2  In Service  42.011865 -87.701317
# ...                ...         ...        ...        ...
# 1414                 2  In Service  41.866225 -87.717918
# 1415                 2  In Service  41.759735 -87.663736
# 1416                19  In Service  41.872187 -87.661501
# 1417                19  In Service  41.896362 -87.654061
# 1418                15  In Service  41.737336 -87.548515
#
#                                       Location nearest_train_station_name  \
# 0                       (41.877505, -87.70485)               Kedzie-Homan
# 1                      (41.914166, -87.716755)               Logan Square
# 2                  (41.73688127, -87.58314552)                       87th
# 3      (41.83068856472101, -87.65621066093445)                    Ashland
# 4                      (42.011865, -87.701317)                     Howard
# ...                                        ...                        ...
# 1414                   (41.866225, -87.717918)                    Pulaski
# 1415                   (41.759735, -87.663736)               Ashland/63rd
# 1416                   (41.872187, -87.661501)                     Racine
# 1417            (41.896362458, -87.6540612729)                    Chicago
# 1418  (41.737335600416664, -87.54851460456847)                       87th
#
#       nearest_train_station_distance         nearest_bus_station_name  \
# 0                           0.140777                 Jackson & Kedzie
# 1                           0.716501          Armitage & Central Park
# 2                           1.335275           87th Street & East End
# 3                           0.468047             35th Street & Racine
# 4                           0.958898                Touhy & Francisco
# ...                              ...                              ...
# 1414                        0.408262             Roosevelt & Lawndale
# 1415                        0.819176            74th Street & Ashland
# 1416                        0.172757                Harrison & Loomis
# 1417                        0.038891  Chicago & Milwaukee (Blue Line)
# 1418                        2.446187          87th Street & Baltimore
#
#       nearest_bus_station_distance  efficiency  Supply_to_Demand     Demand
# 0                         0.031412   52.438123         34.557692   1.346154
# 1                         0.131930   56.120585         36.836575   7.582558
# 2                         0.007877   12.633609          8.100000   1.200000
# 3                         0.019309  108.372510         71.602211   3.347193
# 4                         0.027875   14.637109          9.500000   1.000000
# ...                            ...         ...               ...        ...
# 1414                      0.002163    0.325508          0.000000   0.000000
# 1415                      0.013163    0.397976          0.000000   0.000000
# 1416                      0.083768   19.684723         12.757780  37.920830
# 1417                      0.033492   32.457729         21.361908  26.010023
# 1418                      0.012881   74.420236         48.765399   3.148026
#
# [1419 rows x 15 columns]

# %%
df_min_max_scaled = stations.copy()
column = 'efficiency'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())

# %%
df_min_max_scaled
# Out:
#                 ID                             Station Name  Total Docks  \
# 0     1.594050e+18                   Troy St & Jackson Blvd            9
# 1     6.410000e+02      Central Park Ave & Bloomingdale Ave           11
# 2     1.683530e+18      Public Rack - Cornell Ave & 87th Pl            1
# 3     3.670000e+02                     Racine Ave & 35th St           15
# 4     1.673850e+18  Public Rack - Francisco Ave & Touhy Ave            2
# ...            ...                                      ...          ...
# 1414  1.715850e+18   Public Rack - Lawndale Ave & Roosevelt            2
# 1415  1.715850e+18      Public Rack - Ashland Ave & 74th St            2
# 1416  3.200000e+02                 Loomis St & Lexington St           19
# 1417  5.400000e+01                  Ogden Ave & Chicago Ave           19
# 1418  6.930000e+02                  Baltimore Ave & 87th St           15
#
#       Docks in Service      Status   Latitude  Longitude  \
# 0                    9  In Service  41.877505 -87.704850
# 1                   11  In Service  41.914166 -87.716755
# 2                    1  In Service  41.736881 -87.583146
# 3                   15  In Service  41.830689 -87.656211
# 4                    2  In Service  42.011865 -87.701317
# ...                ...         ...        ...        ...
# 1414                 2  In Service  41.866225 -87.717918
# 1415                 2  In Service  41.759735 -87.663736
# 1416                19  In Service  41.872187 -87.661501
# 1417                19  In Service  41.896362 -87.654061
# 1418                15  In Service  41.737336 -87.548515
#
#                                       Location nearest_train_station_name  \
# 0                       (41.877505, -87.70485)               Kedzie-Homan
# 1                      (41.914166, -87.716755)               Logan Square
# 2                  (41.73688127, -87.58314552)                       87th
# 3      (41.83068856472101, -87.65621066093445)                    Ashland
# 4                      (42.011865, -87.701317)                     Howard
# ...                                        ...                        ...
# 1414                   (41.866225, -87.717918)                    Pulaski
# 1415                   (41.759735, -87.663736)               Ashland/63rd
# 1416                   (41.872187, -87.661501)                     Racine
# 1417            (41.896362458, -87.6540612729)                    Chicago
# 1418  (41.737335600416664, -87.54851460456847)                       87th
#
#       nearest_train_station_distance         nearest_bus_station_name  \
# 0                           0.140777                 Jackson & Kedzie
# 1                           0.716501          Armitage & Central Park
# 2                           1.335275           87th Street & East End
# 3                           0.468047             35th Street & Racine
# 4                           0.958898                Touhy & Francisco
# ...                              ...                              ...
# 1414                        0.408262             Roosevelt & Lawndale
# 1415                        0.819176            74th Street & Ashland
# 1416                        0.172757                Harrison & Loomis
# 1417                        0.038891  Chicago & Milwaukee (Blue Line)
# 1418                        2.446187          87th Street & Baltimore
#
#       nearest_bus_station_distance  efficiency  Supply_to_Demand     Demand
# 0                         0.031412    0.261219         34.557692   1.346154
# 1                         0.131930    0.279586         36.836575   7.582558
# 2                         0.007877    0.062685          8.100000   1.200000
# 3                         0.019309    0.540205         71.602211   3.347193
# 4                         0.027875    0.072678          9.500000   1.000000
# ...                            ...         ...               ...        ...
# 1414                      0.002163    0.001295          0.000000   0.000000
# 1415                      0.013163    0.001657          0.000000   0.000000
# 1416                      0.083768    0.097854         12.757780  37.920830
# 1417                      0.033492    0.161562         21.361908  26.010023
# 1418                      0.012881    0.370860         48.765399   3.148026
#
# [1419 rows x 15 columns]

# %%
stations.to_csv('stations_efficiency.csv')

# %%
import pandas as pd
station_community_mapping = pd.read_csv("StationCommunityMapping.csv")
final_efficiency = pd.read_csv("final_efficiency.csv")

# %%
final_efficiency['community_area'] = station_community_mapping['community_area']

# %%
final_efficiency
# Out:
#       Unnamed: 0.1  Unnamed: 0            ID  \
# 0                0           0  1.594050e+18
# 1                1           1  6.410000e+02
# 2                2           2  1.683530e+18
# 3                3           3  3.670000e+02
# 4                4           4  1.673850e+18
# ...            ...         ...           ...
# 1414          1414        1414  1.715850e+18
# 1415          1415        1415  1.715850e+18
# 1416          1416        1416  3.200000e+02
# 1417          1417        1417  5.400000e+01
# 1418          1418        1418  6.930000e+02
#
#                                  Station Name  Total Docks  Docks in Service  \
# 0                      Troy St & Jackson Blvd            9                 9
# 1         Central Park Ave & Bloomingdale Ave           11                11
# 2         Public Rack - Cornell Ave & 87th Pl            1                 1
# 3                        Racine Ave & 35th St           15                15
# 4     Public Rack - Francisco Ave & Touhy Ave            2                 2
# ...                                       ...          ...               ...
# 1414   Public Rack - Lawndale Ave & Roosevelt            2                 2
# 1415      Public Rack - Ashland Ave & 74th St            2                 2
# 1416                 Loomis St & Lexington St           19                19
# 1417                  Ogden Ave & Chicago Ave           19                19
# 1418                  Baltimore Ave & 87th St           15                15
#
#           Status   Latitude  Longitude  \
# 0     In Service  41.877505 -87.704850
# 1     In Service  41.914166 -87.716755
# 2     In Service  41.736881 -87.583146
# 3     In Service  41.830689 -87.656211
# 4     In Service  42.011865 -87.701317
# ...          ...        ...        ...
# 1414  In Service  41.866225 -87.717918
# 1415  In Service  41.759735 -87.663736
# 1416  In Service  41.872187 -87.661501
# 1417  In Service  41.896362 -87.654061
# 1418  In Service  41.737336 -87.548515
#
#                                       Location nearest_train_station_name  \
# 0                       (41.877505, -87.70485)               Kedzie-Homan
# 1                      (41.914166, -87.716755)               Logan Square
# 2                  (41.73688127, -87.58314552)                       87th
# 3      (41.83068856472101, -87.65621066093445)                    Ashland
# 4                      (42.011865, -87.701317)                     Howard
# ...                                        ...                        ...
# 1414                   (41.866225, -87.717918)                    Pulaski
# 1415                   (41.759735, -87.663736)               Ashland/63rd
# 1416                   (41.872187, -87.661501)                     Racine
# 1417            (41.896362458, -87.6540612729)                    Chicago
# 1418  (41.737335600416664, -87.54851460456847)                       87th
#
#       nearest_train_station_distance         nearest_bus_station_name  \
# 0                           0.140777                 Jackson & Kedzie
# 1                           0.716501          Armitage & Central Park
# 2                           1.335275           87th Street & East End
# 3                           0.468047             35th Street & Racine
# 4                           0.958898                Touhy & Francisco
# ...                              ...                              ...
# 1414                        0.408262             Roosevelt & Lawndale
# 1415                        0.819176            74th Street & Ashland
# 1416                        0.172757                Harrison & Loomis
# 1417                        0.038891  Chicago & Milwaukee (Blue Line)
# 1418                        2.446187          87th Street & Baltimore
#
#       nearest_bus_station_distance  efficiency  Supply_to_Demand     Demand  \
# 0                         0.031412    0.736743         34.557692   1.346154
# 1                         0.131930    0.721076         36.836575   7.582558
# 2                         0.007877    0.933276          8.100000   1.200000
# 3                         0.019309    0.462573         71.602211   3.347193
# 4                         0.027875    0.922366          9.500000   1.000000
# ...                            ...         ...               ...        ...
# 1414                      0.002163    0.992839          0.000000   0.000000
# 1415                      0.013163    0.993199          0.000000   0.000000
# 1416                      0.083768    0.898894         12.757780  37.920830
# 1417                      0.033492    0.834129         21.361908  26.010023
# 1418                      0.012881    0.634221         48.765399   3.148026
#
#           community_area
# 0     EAST_GARFIELD_PARK
# 1           LOGAN_SQUARE
# 2        CALUMET_HEIGHTS
# 3             BRIDGEPORT
# 4             WEST_RIDGE
# ...                  ...
# 1414      NORTH_LAWNDALE
# 1415      WEST_ENGLEWOOD
# 1416      NEAR_WEST_SIDE
# 1417           WEST_TOWN
# 1418       SOUTH_CHICAGO
#
# [1419 rows x 18 columns]

# %%
newDf = pd.DataFrame(final_efficiency.groupby("community_area")["efficiency"].mean()).reset_index(drop=False)

# %%
newDf
# Out:
#     community_area  efficiency
# 0      ALBANY_PARK    0.786598
# 1   ARCHER_HEIGHTS    0.930102
# 2    ARMOUR_SQUARE    0.648272
# 3          ASHBURN    0.996190
# 4   AUBURN_GRESHAM    0.869396
# ..             ...         ...
# 67       WEST_LAWN    0.939729
# 68    WEST_PULLMAN    0.903488
# 69      WEST_RIDGE    0.783805
# 70       WEST_TOWN    0.829581
# 71        WOODLAWN    0.779136
#
# [72 rows x 2 columns]

# %%
newDf.sort_values(["efficiency"],ascending=True)
# Out:
#    community_area  efficiency
# 39  MCKINLEY_PARK    0.561497
# 50      Not Found    0.567921
# 55    ROGERS_PARK    0.595336
# 10     BRIDGEPORT    0.603694
# 22    FULLER_PARK    0.611356
# ..            ...         ...
# 15   CHICAGO_LAWN    0.937906
# 67      WEST_LAWN    0.939729
# 64    WEST_ELSDON    0.950107
# 51        OAKLAND    0.994226
# 3         ASHBURN    0.996190
#
# [72 rows x 2 columns]
